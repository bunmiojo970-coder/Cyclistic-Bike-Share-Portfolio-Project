# %% [markdown]
# # This is an analysis of Cyclistic historical bike trip data in BigQuery to identify trends in how annual members and casual riders use cyclistic bikes from 2020 to 2025.
#
# # Aim
# 1. Understand how annual members and casual riders differ in the way they use cyclistic bikes.
# 2. Why casual riders would buy a membership?
# 3. Design marketing strategies aimed at converting casual riders into annual members.
#
# ### For January, February, March, April, May, November, December 2025.
# * To analyze casual riders and annual members rows using UNION ALL function.

# %%
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_01` 


UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_02` 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_03` 


UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_04`  


UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_05`

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_11` 
 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_12`

ORDER BY ride_length_seconds DESC;



SELECT 
member_casual,
COUNT(member_casual) as number
 FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025 UNION ALL`
 group by member_casual
 order by number desc;

# %% [markdown]
# * There was approximately three times more annual members than casual riders.
# * Then,to analyze casual riders rows:

# %%
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_01` 
WHERE
member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_02`
WHERE
member_casual = 'casual' 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_03` 
WHERE
member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_04`  
WHERE
member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_05`
WHERE
member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_11` 
WHERE
member_casual = 'casual' 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_12`
WHERE
member_casual = 'casual' 
ORDER BY ride_length_seconds DESC;




SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025 UNION ALL casual`
GROUP BY rideable_type
ORDER BY avg_rls desc;

# %% [markdown]
# * Classic bike was used more by the casual riders in 2025 because it had the highest average ride length in seconds.
# * To analyze the annual member rows by deriving the average ride length in seconds for each bike or rideable type and day name:

# %%
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_01` 
WHERE
member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_02`
WHERE
member_casual = 'member' 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_03` 
WHERE
member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_04`  
WHERE
member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_05`
WHERE
member_casual = 'member'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_11` 
WHERE
member_casual = 'member' 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2025_12`
WHERE
member_casual = 'member' 
ORDER BY ride_length_seconds DESC;







SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_2023.2025 UNION ALL member`
GROUP BY rideable_type
ORDER BY avg_rls desc;



SELECT 
day_name,
COUNT(day_name) AS frequency,
AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Cyclistic_2023.2025 UNION ALL member`
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * Classic bike was also the most used by annual members with the highest average ride length in seconds (831.754seconds).
# * Sunday had the highest frequency of 228305

# %% [markdown]
# #### Now, to analyze the 2024 dataset(April, May, June, July, October, November, December) for annual members and casual riders using the same pattern of codes as above.
#
# * To analyze casual riders and annual members rows using UNION ALL function.

# %%
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_01` 

 
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_02` 


UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_03`

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_04`


UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_11` 

UNION ALL


SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_12`

ORDER BY ride_length_seconds DESC;




--To derive the number of casual riders and annual members
SELECT 
member_casual,
COUNT(member_casual) as number
 FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_UNION ALL` 
 group by member_casual
 order by number desc;

# %% [markdown]
# There was approximately three times more annual members than casual riders in this dataset.

# %%
--To derive the table for all casual riders
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_01` 
WHERE member_casual = 'casual'
 
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_02` 
WHERE member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_03`
WHERE member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_04`
WHERE member_casual = 'casual'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_11` 
WHERE member_casual = 'casual'

UNION ALL


SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_12`
WHERE member_casual = 'casual'

ORDER BY ride_length_seconds DESC;




--To derive the table for all annual members
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_01` 
WHERE member_casual = 'member'
 
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_02` 
WHERE member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_03`
WHERE member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_04`
WHERE member_casual = 'member'

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_11` 
WHERE member_casual = 'member'

UNION ALL


SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
EXTRACT (YEAR FROM started_at) AS year,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024_12`
WHERE member_casual = 'member'

ORDER BY ride_length_seconds DESC;

# %%
--To determine the average ride length in seconds for each bike type for all casual riders
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024 UNION ALL casual` 
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all casual riders
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024 UNION ALL casual` 
GROUP BY day_name
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each bike type for all annual members
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024 UNION ALL member`
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all annual members
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2024 UNION ALL member`
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * For casual riders, classic bikes had the highest average ride length in seconds (2193.7951 seconds) for bike types. Sunday had the highest average ride length in seconds (1738.0234 seconds) per day name. Saturday had the highest frequency per day name with 83806.
#
# * For annual members, classic bikes also had the highest average ride length in seconds (842.0411 seconds). Sunday had the highest average ride length in seconds (802.5628 seconds). Wednesday had the highest frequency per day name (203654).

# %% [markdown]
# ## For January, February, March, April, November, December of 2023.
# * To analyze the annual members and casual rider rows.
# * Then to analyze the casual riders rows alone.

# %%
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_01`
 
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Bike_Share.2023_02`

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_03`  

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
 FROM `extended-ward-451121-a9.Cyclistic_2023.2023_04` 

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_11`

UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2023_12` 

ORDER BY ride_length_seconds DESC;
 


--To derive the number of casual riders and annual members
SELECT 
member_casual,
COUNT(member_casual) as number
 FROM `extended-ward-451121-a9.Bike_Share.2023 UNION ALL member_casual`
 group by member_casual
 order by number desc;


--To derive the table for all casual riders
SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_01`
WHERE member_casual = 'casual'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Bike_Share.2023_02`
WHERE member_casual = 'casual'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_03`  
WHERE member_casual = 'casual'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_04` 
WHERE member_casual = 'casual'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_11`
WHERE member_casual = 'casual'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2023_12` 
WHERE member_casual = 'casual'

ORDER BY ride_length_seconds DESC;
 







--To derive the table for all annual members

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_01`
WHERE member_casual = 'member'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Bike_Share.2023_02`
WHERE member_casual = 'member'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_03`  
WHERE member_casual = 'member'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
 FROM `extended-ward-451121-a9.Cyclistic_2023.2023_04` 
WHERE member_casual = 'member' 
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_2023.2023_11`
WHERE member_casual = 'member'
UNION ALL

SELECT
member_casual,
rideable_type,
TIMESTAMP_DIFF(ended_at, started_at, SECOND) AS ride_length_seconds,
DATE(started_at) AS date,
FORMAT_TIMESTAMP ('%A', ended_at) AS day_name
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2023_12` 
WHERE member_casual = 'member'
ORDER BY ride_length_seconds DESC;

# %% [markdown]
# * Here also, the annual members in 2023 had approximately three times more rows than casual riders.

# %%
--To determine the average ride length in seconds for each bike type for all casual riders
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_2023.UNION ALL 2023 casual`
GROUP BY rideable_type
ORDER BY avg_rls desc;



--To determine the average ride length in seconds for each day name for all casual riders
SELECT 
day_name,
COUNT(day_name) AS frequency,
AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_2023.UNION ALL 2023 casual`
GROUP BY day_name
ORDER BY avg_rls desc;



--To determine the average ride length in seconds for each bike type for all annual members
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_2023.2023 UNION ALL member`
GROUP BY rideable_type
ORDER BY avg_rls desc;



--To determine the average ride length in seconds for each day name for all annual members
SELECT 
day_name,
COUNT(day_name) AS frequency,
AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_2023.2023 UNION ALL member`
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * For casual riders, docked bikes had the highest average ride length in seconds (9002.318 seconds) for bike types. Monday had the highest average ride length in seconds(1877.2891 seconds) in seconds per day name. Saturday had the highest frequency per day name with 80440.
# * For annual members, classic bikes also had the highest average ride length in seconds(744.483 seconds). Sunday had the highest average ride length in seconds (749.4492 seconds). Wednesday had the highest frequency per day name (204447).

# %% [markdown]
# #### Now, to analyze the 2022 dataset(January, February, March, April, November, December) for annual members and casual riders using the same pattern of codes as above.

# %%
--To count the number of annual members and casual riders among the 2022 dataset.
SELECT 
member_casual,
COUNT(member_casual) as number
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2022_UNION ALL_member_casual`
 group by member_casual
 order by number desc;

# %% [markdown]
# * There was approximately two and half times more Annual members than casual riders in this dataset.

# %%
--To determine the average ride length in seconds for each bike type for all casual riders
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
  FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2022_UNION ALL_casual` 
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all casual riders
SELECT 
day_name,
COUNT(day_name) AS frequency,
AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2022_UNION ALL_casual` 
GROUP BY day_name
ORDER BY avg_rls desc;


--To determine the average ride length in seconds for each bike type for all annual members
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
   FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2022_UNION ALL_member` 
GROUP BY rideable_type
ORDER BY avg_rls desc;


--To determine the average ride length in seconds for each day name for all annual members
SELECT 
day_name,
COUNT(day_name) AS frequency,
AVG (ride_length_seconds) AS avg_rls
  FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.2022_UNION ALL_member` 
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * For casual riders, docked bikes had the highest average ride length in seconds (6981.6954 seconds) for bike types. Monday had the highest average ride length in seconds (2019.4037 seconds) in seconds per day name. Saturday had the highest frequency per day name with 77090.
# * For annual members, classic bikes also had the highest average ride length in seconds (745.3192 seconds). Sunday had the highest average ride length in seconds (761.9203 seconds). Tuesday had the highest frequency per day name (173020).

# %% [markdown]
# #### Now, to analyze the 2021 dataset (January, February, March, May, December) for annual members and casual riders using the same pattern of codes as above.

# %%
--To count the number of annual members and casual riders from the 2021 dataset.
SELECT 
member_casual,
COUNT(member_casual) as number
 FROM `extended-ward-451121-a9.Bike_Share.2021 UNION_ALL member_casual` 
 group by member_casual
 order by number desc;

# %% [markdown]
# * There was approximately two times more annual members than casual riders in this dataset.

# %%
--To determine the average ride length in seconds for each bike type for all casual riders
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
   FROM `extended-ward-451121-a9.Bike_Share.2021 UNION ALL  casual`  
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all casual riders
SELECT 
day_name,
  COUNT(day_name) AS frequency,
  AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2021 UNION ALL  casual`
GROUP BY day_name
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each bike type for all annual members
SELECT rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2021 UNION ALL member`   
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all annual members
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2021 UNION ALL member`  
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * For casual riders, docked bikes had the highest average ride length in seconds (5211.3415 seconds) for bike types. Sunday had the highest average ride length in seconds (2460.140 seconds) in seconds per day name. Saturday had the highest frequency per day name with 105072.
# * For annual members, classic bikes also had the highest average ride length in seconds (864.1598 seconds). Sunday had the highest average ride length in seconds (944.5398 seconds). Wednesday had the highest frequency per day name (114017).

# %% [markdown]
# #### Now, to analyze the 2020 dataset (April, May, June, July, October, November, December) for annual members and casual riders using the same pattern of codes as above.

# %%
--To count the number of annual members and casual riders from the 2020 dataset.
SELECT 
member_casual,
COUNT(member_casual) as number
 FROM `extended-ward-451121-a9.Bike_Share.2020 UNION ALL` 
 group by member_casual
 order by number desc;

# %% [markdown]
# * There was approximately two times more annual members than casual riders in this dataset.

# %%
--To determine the average ride length in seconds for each bike type for all casual riders
SELECT 
rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
 FROM `extended-ward-451121-a9.Bike_Share.2020 UNION ALL casual`
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all casual riders
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 UNION ALL casual`
GROUP BY day_name
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each bike type for all annual members
SELECT 
rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 UNION ALL member` 
GROUP BY rideable_type
ORDER BY avg_rls desc;

--To determine the average ride length in seconds for each day name for all annual members
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 UNION ALL member` 
GROUP BY day_name
ORDER BY avg_rls desc;

# %% [markdown]
# * For casual riders, docked bikes had the highest average ride length in seconds (3145.1864 seconds) for bike types. Monday had the highest average ride length in seconds (3344.3805 seconds) per day name. Saturday had the highest frequency per day name with 183200.
# * For annual members, classic bikes also had the highest average ride length in seconds (793.5006 seconds) per bike type. Saturday had the highest average ride length in seconds (1111.6141 seconds). Saturday also had the highest frequency per day name (183625).

# %%
--To derive the bike type with the highest frequency for all casual riders from 2020 to 2025
SELECT 
rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 casual UNION ALL`
GROUP BY rideable_type
ORDER BY number_of_type desc;


--To derive the day name with the highest frequency for all casual riders from 2020 to 2025
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 casual UNION ALL`
GROUP BY day_name
ORDER BY frequency desc;

--To derive the bike type with the highest frequency for all annual members from 2020 to 2025
SELECT 
rideable_type,
   COUNT (rideable_type) AS number_of_type,
   AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 member UNION ALL`
GROUP BY rideable_type
ORDER BY number_of_type desc;

--To derive the day name with the highest frequency for all annual members from 2020 to 2025
SELECT 
day_name,
 COUNT(day_name) AS frequency,
 AVG (ride_length_seconds) AS avg_rls
FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 member UNION ALL`
GROUP BY day_name
ORDER BY frequency desc;




--Total count of annual members and casual riders all throughout 2020 to 2025
SELECT
member_casual,
rideable_type,
ride_length_seconds,
year,
day_name
FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 casual UNION ALL`

UNION ALL

SELECT
member_casual,
rideable_type,
ride_length_seconds,
year,
day_name
 FROM `extended-ward-451121-a9.Bike_Share.2020 - 2025 member UNION ALL`

--
SELECT 
member_casual,
COUNT(member_casual) as number
FROM `extended-ward-451121-a9.Cyclistic_Bike_Share.ALL 2020 -2025 member_casual` 
 group by member_casual
 order by number desc;

# %% [markdown]
# ### **Key Findings**
#
# 1. Overall, there are approximately two times more annual members than casual riders from 2020 to 2025
# 2. Overall, electric bikes had the most frequency of use for both annual members and casual riders from 2020 to 2025.
# 3. Overall, saturday and sunday had the highest frequency of use and average ride length respectively for all casual riders from 2020 to 2025.
# 4. Overall, sunday also had the highest average ride length while thursday had the highest frequency of use for all annual members from 2020 to 2025.
# 5. Overall, the classic bikes had the highest average ride length for all annual members 2020 to 2025.
# 6. Overall, the docked bikes had the highest average ride length for all casual riders from 2020 to 2025.
#
#
#
# ### **Recommendations**
#
# 1. Restrict access to electric bikes to only annual members on Sunday and Saturdays since these are the days with the highest average ride length covered and highest frequency of use respectively by the casual riders.This will make many of the casual riders consider subscribing to become annual members to get access to their preferred orders leading to more profit for the company.
# 2. Another approach would be to send all casual riders a weekly email notification about a very good discount only on saturdays and sundays (e.g 10%) on the pricing plan to convert their subscription to annual membership.
